# %%
def setup(): 
    size(600,600)
    background('#D3D0CB')
    stroke('#FFFFFF')
    
    # This variable will come in handy. Trust me.
    jitter = 0
    
    for j in range(8):
        for i in range(8):
            fill('#E2C044')
            quad(50+65*i + random(-jitter, jitter), 50 + 65*j + random(-jitter, jitter), # top-left corner
                 50 + 65*i + random(-jitter, jitter) , 100+ 65*j + random(-jitter, jitter), # lower-left
                 100 + 65*i + random(-jitter, jitter), 100 + 65*j + random(-jitter, jitter), # lower-right corner
                 100 + 65*i + random(-jitter, jitter), 50 + 65*j + random(-jitter, jitter)) # top-right corner
            jitter = jitter + 0.2

# %%
run_sketch()
