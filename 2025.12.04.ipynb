# %%
cores = ["#ACDEB2", "#E1EAB5", "#EDAD9E"]

# %%
def setup():
    size(600,600)
    background(16, 14, 41)
    for i in range(23):
        for j in range(23):
            random_1 = random_int(2)
            
            if random_1 == 0:
                fill(random_choice(cores))
                rect(25*i+10,25*j+10,20,20)
            if random_1 == 1:
                fill(random_choice(cores))
                circle(25*i+20,25*j+20,20)
            if random_1 == 2:
                pass
     
    #rect(10,10,10,10)
def draw():
    pass

# %%
run_sketch()
